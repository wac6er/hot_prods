# %% [markdown]
# **Notes:** need to download the csv ('https://docs.google.com/spreadsheets/d/1j1zp8yHJbXMwSe58bW38MODuD9wOYDWfPhklsKTqjqI/edit?usp=sharing'), copy/change path and create df in step 1. Change the user agen in 'headers' to your user agent (search 'my user agent' in chrome).
#
# Be careful not to exceed Amazon's request rate limit! The first scrape takes aat least 30 mins!

# %%
#import packages
import pandas as pd
import numpy as np
import requests
import time
import bs4
from bs4 import BeautifulSoup
import random
import re

#default mode
scraper_path = '/content/Arms_AMZN - Sheet1 (1).csv' #download the spreadsheet that directs the bot at 'https://docs.google.com/spreadsheets/d/1j1zp8yHJbXMwSe58bW38MODuD9wOYDWfPhklsKTqjqI/edit?usp=sharing', its pretty straightforward
wait_time = 5
new_releases = 'https://www.amazon.com/gp/new-releases/'
best_sellers = 'https://www.amazon.com/Best-Sellers/zgbs/ref=zg_bsnr_tab'
movers_and_shakers = 'https://www.amazon.com/gp/movers-and-shakers/ref=zg_bs_tab'
most_wished_for = 'https://www.amazon.com/gp/most-wished-for/ref=zg_bsms_tab'
gift_ideas = 'https://www.amazon.com/gp/most-gifted/ref=zg_mw_tab'

website = new_releases



print('would you like to run in default mode? (yes/no) if so, set parameters up top')
default= input()
if default == 'yes':
  print('default is on')
else:
  print('enter the path to the shared file above, after downloading+copying')
  scraper_path = input()
  print('seconds between url requests are randomly spread between 1 and an upper integer, enter your integer [longer: (10-15s) more complete, (3-5s) short: faster]')
  wait_time = int(input())
  print('which AMZN ranked category would you like to scrape? ("best sellers","new releases", "most wished for", "gift ideas"')
  category = input()
  category = str(category).lower()
  if category == 'best sellers':
    website = best_sellers
  else: 
    print('not best sellers')
  if category == 'new releases':
    website = new_releases
  else: 
    print('not new releases')
  if category == 'most wished for':
    website = most_wished_for
  else: 
    print('not most wished for')
  if category == 'gift ideas':
    website = gift_ideas
  else: 
    print('not gift ideas')
print('is this a test run? if so, enter "yes"')
try_ = input()
if try_ == 'yes':
  print('how many categories would you like to scrape? It starts at the top...')
  print('note: no point in testing >2 categories unless you would like to test >15 (most links just repeat)')
  test_iterations = int(input())
else:
  print('the full run takes a while!')
df = pd.read_csv(scraper_path)

#get page url's for all individual categories (note: URL IS VARIABLE, you should be able to use best sellers or another ranked AMZ category)
cat_names1 = {'names':[]}
cat_names2 = {'names':[]}
cat_names3 = {'names':[]}

if try_ == 'yes':
  try_or_not = test_iterations
else:
  try_or_not = len(df)

for x in range(try_or_not):
  try:
    num2 = df['second_arm'][x]
    num2 = int(num2) - 1
  except:
    print('num2 problem')
  try:
    num3 = df['third_arm'][x]
    num3 = int(num3) - 1
  except:
    print('num3 problem')
  try:
    url = website
    headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.51 Safari/537.36'}
    cat_names = {'names':[]}
    html = requests.get(url,headers = headers).text
    soup = bs4.BeautifulSoup(html, "html.parser")
    for tag in soup.findAll("div", {"class": "_p13n-zg-nav-tree-all_style_zg-browse-item__1rdKf _p13n-zg-nav-tree-all_style_zg-browse-height-small__nleKL"}):
            cat_names['names'].append(tag.findNext("a"))
  except:
    print('arm 1 error')
  try:
    url = 'https://www.amazon.com'+ str(cat_names['names'][num2]).split('"')[1]
    html = requests.get(url,headers = headers).text
    soup = bs4.BeautifulSoup(html, "html.parser")
    for tag in soup.findAll("div", {"class": "_p13n-zg-nav-tree-all_style_zg-browse-group__88fbz"}):
            cat_names1['names'].append(tag.findAll("a"))
  except:
      print('arm 2 error')
  try:
    cat_names1['names']
    url2 = 'https://www.amazon.com'+ str(cat_names1['names'][num3]).split('"')[1]
    html = requests.get(url2,headers = headers).text
    soup = bs4.BeautifulSoup(html, "html.parser")
    for tag in soup.findAll("div", {"class": "_p13n-zg-nav-tree-all_style_zg-browse-item__1rdKf _p13n-zg-nav-tree-all_style_zg-browse-height-large__1z5B8"}):
            cat_names2['names'].append(tag.findAll("a"))
  except:
    print('arm 3 error')
  time.sleep(random.randint(1, wait_time))

#collect all collected links, droping any duplicates
all1 = {'link':[],'name':[]}
for x in range(len(cat_names1['names'])):
  for xx in range(len(cat_names1['names'][x])):
    all1['link'].append('https://www.amazon.com'+str(cat_names1['names'][x][xx]).split('"')[1])
    all1['name'].append(str(cat_names1['names'][x][xx]).split('"')[2])
print('length of secondary links collected is '+str(len(pd.DataFrame(all1['link']).drop_duplicates())))
print('length of secondary names collected is '+str(len(pd.DataFrame(all1['name']).drop_duplicates())))

all2 = {'link':[],'name':[]}
for x in range(len(cat_names2['names'])):
  for xx in range(len(cat_names2['names'][x])):
    all2['link'].append('https://www.amazon.com'+str(cat_names2['names'][x][xx]).split('"')[1])
    all2['name'].append(str(cat_names2['names'][x][xx]).split('"')[2])
print('length of primary links collected is '+str(len(pd.DataFrame(all2['link']).drop_duplicates())))
print('length of primary names collected is '+str(len(pd.DataFrame(all2['name']).drop_duplicates())))

#mor orgnaization... getting top then bottom level urls
aaa = pd.DataFrame()
aaa['link'] = pd.DataFrame(all2['link']).drop_duplicates()[0]
aaa['name'] = pd.DataFrame(all2['name']).drop_duplicates()[0]
aa = pd.DataFrame()
aa[['link','name']] = pd.merge(pd.DataFrame(all1['link']).reset_index(),pd.DataFrame(all1['name']).reset_index(), on = 'index').drop(columns = 'index').drop_duplicates()
aa = aa.append(aaa)
aa = aa.reset_index()
aa = aa.sort_values('index').drop(columns = 'index')

cat_names = {'price':[]}
cat_names1 = {'price':[]}
saverr_ = {'index':[],'imageLink':[],'imageLink1':[],'brand':[]}
saver_ = {'index':[],'imageLink':[],'imageLink1':[],'brand':[]}
saver = {'index':[],'rating':[],'ratingCount':[]}
saverr = {'index':[],'rating':[],'ratingCount':[]}

if try_ == 'yes':
  try_or_not = test_iterations
else:
  try_or_not = len(aa['link'])

zy_ = 0
zy = 0
zyy_=0
zyy = 0


for x in range(try_or_not):
  try:
    url = aa['link'][x]
    url2 = str(aa['link'][x]).split('ref=')[0]+'ref='+str(aa['link'][x]).split('ref=')[1].split("_1")[0]+'_2?ie=UTF8&pg=2'
    headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.51 Safari/537.36'}
    html = requests.get(url,headers = headers).text
    soup = bs4.BeautifulSoup(html, "html.parser")
    for tag in soup.findAll("div", {"class": "a-section a-spacing-mini _p13n-zg-list-grid-desktop_maskStyle_noop__3Xbw5"}):
            tt = {'imageLink':[]}
            tt['imageLink'].append(tag.findAll("img"))
            if len(tt['imageLink'])>=1:
              for x in range(len(tt['imageLink'])):
                zzz = str(tt['imageLink'][x]).split('"')[1]
                if zzz =="' class=":
                  saverr_['brand'].append(str(tt['imageLink'][x]).split('"')[2])
                else:
                  saverr_['brand'].append(zzz)
                  
                z = str(tt['imageLink'][x]).split('"')[5]
                zz = str(tt['imageLink'][x]).split('"')[7]
                if len(z)>=15:
                  saverr_['imageLink'].append(z)
                else:
                  saverr_['imageLink'].append(str(tt['imageLink'][x]).split('"')[4])
                if len(zz)>=15:                                
                  saverr_['imageLink1'].append(zz)
                else:
                  saverr_['imageLink1'].append(str(tt['imageLink'][x]).split('"')[6])
                saverr_['index'].append(zyy_)
                zyy_=zyy_+1
            else:
              print()
    for tag in soup.findAll("div", {"class": "a-icon-row"}):
            x = tag.findNext("span").text
            xxx = tag.findNext("span", {"class": "a-size-small"}).text
            if len(x)>=1:
              saverr['rating'].append(x)
              saverr['index'].append(zy)
            else:
              print()
            if len(xxx)>=1:
              saverr['ratingCount'].append(xxx)
            else:
              print()
            zy = zy+1
    for tag in soup.findAll("span", {"class": "a-size-base a-color-price"}):
            x = tag.findNext("span",{"class":"_p13n-zg-list-grid-desktop_price_p13n-sc-price__3mJ9Z"}).text
            if len(x)>=1:
              cat_names['price'].append(x)
            else:
              cat_names['price'].append(str(url))
  except:
    print('first 50, error with link: '+ str(url))

  time.sleep(random.randint(1,wait_time))
#-------------------------------------------------------------------------------------------------------------
  try:
    html1 = requests.get(url2,headers = headers).text
    soup1 = bs4.BeautifulSoup(html1, "html.parser")
    for tag in soup1.findAll("div", {"class": "a-section a-spacing-mini _p13n-zg-list-grid-desktop_maskStyle_noop__3Xbw5"}):
            tt = {'imageLink':[]}
            tt['imageLink'].append(tag.findAll("img"))
            if len(tt['imageLink'])>=1:
              for x in range(len(tt['imageLink'])):
                zzz = str(tt['imageLink'][x]).split('"')[1]
                if zzz =="' class=":
                  saver_['brand'].append(str(tt['imageLink'][x]).split('"')[2])
                else:
                  saver_['brand'].append(zzz)
                z = str(tt['imageLink'][x]).split('"')[5]
                zz = str(tt['imageLink'][x]).split('"')[7]
                if len(z)>=15:
                  saver_['imageLink'].append(z)
                else:
                  saver_['imageLink'].append(str(tt['imageLink'][x]).split('"')[4])
                if len(zz)>=15:                                
                  saver_['imageLink1'].append(zz)
                else:
                  saver_['imageLink1'].append(str(tt['imageLink'][x]).split('"')[6])
                saver_['index'].append(zy_)
                zy_ = zy_+1
            else:
              print()
            
    for tag in soup1.findAll("div", {"class": "a-icon-row"}):
            x = tag.findNext("span",{"class":"a-icon-alt"}).text
            xxx = tag.findNext("span", {"class": "a-size-small"}).text
            if len(x)>=1:
              saver['rating'].append(x)
              saver['index'].append(zyy)
            else:
              print()
            if len(xxx)>=1:
              saver['ratingCount'].append(xxx)
            else:
              print()
            zyy = zyy+1

    for tag in soup1.findAll("span", {"class": "a-size-base a-color-price"}):
            x = tag.findNext("span",{"class":"_p13n-zg-list-grid-desktop_price_p13n-sc-price__3mJ9Z"}).text
            if len(x)>=1:
              cat_names1['price'].append(x)
            else:
              cat_names1['price'].append(str(url2))

    print(len(cat_names1['imageLink']))
    print(len(cat_names1['imageLink1']))
    print(len(cat_names1['brand']))
    print(len(cat_names1['price']))

  except:
    print('second 50, error with link: '+ url2)
  
  time.sleep(random.randint(1,wait_time))


df = pd.DataFrame(cat_names)
df = df.reset_index()
df = pd.merge(df,pd.DataFrame(saverr),on='index')
df = pd.merge(df,pd.DataFrame(saverr_), on = 'index')
df1 = pd.DataFrame(cat_names1)
df1 = df1.reset_index()
df1 = pd.merge(df1,pd.DataFrame(saver), on = 'index')
df1 = pd.merge(df1,pd.DataFrame(saver_), on = 'index')


def find_number(text):
    num = re.findall(r'[0-9]+',text)
    return " ".join(num)
df['rating_num']=df['rating'].apply(lambda x: find_number(x))
df1['rating_num']=df1['rating'].apply(lambda x: find_number(x))
df['price']=df1['price'].apply(lambda x: find_number(x))
df['price']=df1['price'].apply(lambda x: find_number(x))


listt = []
for x in range(len(df)):
  try:
    listt.append((int(df['rating_num'].iloc[x].split()[0])+int(df['rating_num'].iloc[x].split()[1])*.1)/int(df['rating_num'].iloc[x].split()[2]))
  except:
    listt.append('error')

df['rating_num'] = listt
listt = []
for x in range(len(df1)):
  try:
    listt.append((int(df1['rating_num'].iloc[x].split()[0])+int(df1['rating_num'].iloc[x].split()[1])*.1)/int(df1['rating_num'].iloc[x].split()[2]))
  except:
    listt.append('error')

df1['rating_num'] = listt

listt = []
for x in range(len(df)):
  try:
    listt.append(df['price'].iloc[x].replace('$',""))
  except:
    listt.append('error')
df['price'] = listt

listt = []
for x in range(len(df1)):
  try:
    listt.append(df1['price'].iloc[x].replace('$',""))
  except:
    listt.append('error')
df1['price'] = listt

pieces = (df1,df)
df_final = pd.concat(pieces, ignore_index = True)
df_final = df_final.drop(columns ='rating')
df_final = df_final.drop(columns = 'index')
df_final
# Out:
# would you like to run in default mode? (yes/no) if so, set parameters up top
# yes
# default is on
# is this a test run? if so, enter "yes"
# no
# the full run takes a while!
# arm 2 error
# arm 2 error
# arm 2 error
# arm 2 error
# arm 2 error
# arm 2 error
# arm 2 error
# arm 2 error
# arm 2 error
# arm 2 error
# arm 2 error
# arm 2 error
# arm 2 error
# arm 2 error
# arm 2 error
# arm 2 error
# arm 2 error
# arm 2 error
# arm 2 error
# length of secondary links collected is 511
# length of secondary names collected is 479
# length of primary links collected is 20
# length of primary names collected is 20
# second 50, error with link: https://www.amazon.com/gp/new-releases/amazon-devices/370783011/ref=zg_bsnr_nav_amazon-devices_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/amazon-devices/2102313011/ref=zg_bsnr_nav_amazon-devices_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/13270237011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/17863429011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/21217716011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/21217719011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/21217720011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/21601413011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/21389970011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/23557436011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/21403269011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/23536802011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/21596710011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/23511013011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/23548209011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/23511014011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/21425079011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/23557439011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/21442712011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/21317470011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/21417971011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/21317469011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/21362311011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/13226812011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/21559224011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/21362312011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/15684313011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/15684301011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/23496428011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/23602499011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/21403265011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/21499231011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/23602498011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/21614090011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/21179680011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/21179681011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/15389784011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/21179674011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/21179679011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/21179675011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/21179682011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/21179676011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/15684306011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/21491764011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/21179678011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/21179677011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/23680130011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/21390573011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/21390581011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/21390575011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/21390579011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/21390576011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/21390580011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/21390578011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/21542441011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/21346125011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/21390577011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/boost/21390574011/ref=zg_bsnr_nav_boost_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/appliances/2242350011/ref=zg_bsnr_nav_appliances_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/appliances/3741261/ref=zg_bsnr_nav_appliances_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/appliances/3741271/ref=zg_bsnr_nav_appliances_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/appliances/3741331/ref=zg_bsnr_nav_appliances_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/appliances/2399939011/ref=zg_bsnr_nav_appliances_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/appliances/3741441/ref=zg_bsnr_nav_appliances_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/appliances/3741411/ref=zg_bsnr_nav_appliances_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/appliances/3741361/ref=zg_bsnr_nav_appliances_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/appliances/3741481/ref=zg_bsnr_nav_appliances_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/appliances/2399955011/ref=zg_bsnr_nav_appliances_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/appliances/2383576011/ref=zg_bsnr_nav_appliances_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/appliances/3741521/ref=zg_bsnr_nav_appliances_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/mobile-apps/9408444011/ref=zg_bsnr_nav_mobile-apps_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/mobile-apps/10298305011/ref=zg_bsnr_nav_mobile-apps_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/mobile-apps/9408466011/ref=zg_bsnr_nav_mobile-apps_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/mobile-apps/9408481011/ref=zg_bsnr_nav_mobile-apps_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/mobile-apps/9408490011/ref=zg_bsnr_nav_mobile-apps_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/mobile-apps/9408433011/ref=zg_bsnr_nav_mobile-apps_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/mobile-apps/9408523011/ref=zg_bsnr_nav_mobile-apps_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/mobile-apps/9209902011/ref=zg_bsnr_nav_mobile-apps_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/mobile-apps/9408749011/ref=zg_bsnr_nav_mobile-apps_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/mobile-apps/9408582011/ref=zg_bsnr_nav_mobile-apps_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/mobile-apps/9408710011/ref=zg_bsnr_nav_mobile-apps_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/mobile-apps/10298309011/ref=zg_bsnr_nav_mobile-apps_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/mobile-apps/9408805011/ref=zg_bsnr_nav_mobile-apps_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/mobile-apps/10298306011/ref=zg_bsnr_nav_mobile-apps_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/mobile-apps/9408765011/ref=zg_bsnr_nav_mobile-apps_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/mobile-apps/9408771011/ref=zg_bsnr_nav_mobile-apps_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/mobile-apps/9408802011/ref=zg_bsnr_nav_mobile-apps_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/mobile-apps/9408852011/ref=zg_bsnr_nav_mobile-apps_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/mobile-apps/9408874011/ref=zg_bsnr_nav_mobile-apps_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/mobile-apps/9408449011/ref=zg_bsnr_nav_mobile-apps_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/mobile-apps/9408491011/ref=zg_bsnr_nav_mobile-apps_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/mobile-apps/9408875011/ref=zg_bsnr_nav_mobile-apps_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/mobile-apps/9408464011/ref=zg_bsnr_nav_mobile-apps_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/mobile-apps/9408876011/ref=zg_bsnr_nav_mobile-apps_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/mobile-apps/10298308011/ref=zg_bsnr_nav_mobile-apps_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/mobile-apps/9408785011/ref=zg_bsnr_nav_mobile-apps_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/mobile-apps/9408914011/ref=zg_bsnr_nav_mobile-apps_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/mobile-apps/9408850011/ref=zg_bsnr_nav_mobile-apps_2?ie=UTF8&pg=2
# second 50, error with link: https://www.amazon.com/gp/new-releases/arts-crafts/
# 13721   error       2,448  https://images-na.ssl-images-amazon.com/images...
# 13722   error       2,448  https://images-na.ssl-images-amazon.com/images...
#
#                                               imageLink1  \
# 0      https://images-na.ssl-images-amazon.com/images...
# 1      https://images-na.ssl-images-amazon.com/images...
# 2      https://images-na.ssl-images-amazon.com/images...
# 3      https://images-na.ssl-images-amazon.com/images...
# 4      https://images-na.ssl-images-amazon.com/images...
# ...                                                  ...
# 13718  https://images-na.ssl-images-amazon.com/images...
# 13719  https://images-na.ssl-images-amazon.com/images...
# 13720  https://images-na.ssl-images-amazon.com/images...
# 13721  https://images-na.ssl-images-amazon.com/images...
# 13722  https://images-na.ssl-images-amazon.com/images...
#
#                                                    brand  rating_num
# 0      Introducing Ring Power Pack – stackable backup...        0.98
# 1      All New, Made for Amazon, Disney Mickey Mouse-...        0.96
# 2      NuPro Book Cover for Kindle Paperwhite, Black ...        0.92
# 3      Blink Outdoor + Solar Panel Charging Mount – w...        0.72
# 4         Fire TV Stick Lite with 2-Year Protection Plan        0.92
# ...                                                  ...         ...
# 13718  Secura Electric Milk Frother, Automatic Milk S...        0.94
# 13719  Gorilla Grip Airtight Vacuum Sealer Bags, 6x F...        0.96
# 13720  Toaster 4 Slices, DyBaxa Stainless Steel Toast...        0.96
# 13721  DEVENTORZ Milk Frother Handheld, Electric Milk...        0.94
# 13722  (2022 New Upgraded) Vacuum Sealer Machine, Aut...        0.94
#
# [13723 rows x 6 columns]

# %%
#backup

# %%
cat_names = {'imageLink':[],'imageLink1':[],'brand':[],'rating':[],'ratingCount':[],'price':[]}
cat_names1 = {'imageLink':[],'imageLink1':[],'brand':[],'rating':[],'ratingCount':[],'price':[]}

if try_ == 'on':
  try_or_not = test_iterations
else:
  try_or_not = len(aa['link'])
for x in range(try_or_not):
  try:
    url = aa['link'][x]
    url2 = str(aa['link'][x]).split('ref=')[0]+'ref='+str(aa['link'][x]).split('ref=')[1].split("_1")[0]+'_2?ie=UTF8&pg=2'
    headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.51 Safari/537.36'}
    html = requests.get(url,headers = headers).text
    soup = bs4.BeautifulSoup(html, "html.parser")
    for tag in soup.findAll("div", {"class": "a-section a-spacing-mini _p13n-zg-list-grid-desktop_maskStyle_noop__3Xbw5"}):
            tt = {'imageLink':[]}
            tt['imageLink'].append(tag.findAll("img"))
            if len(tt['imageLink'])>=1:
              for x in range(len(tt['imageLink'])):
                cat_names['brand'].append(str(tt['imageLink'][x]).split('"')[1])

                z = str(tt['imageLink'][x]).split('"')[5]
                zz = str(tt['imageLink'][x]).split('"')[7]
                if len(z)>=15:
                  cat_names['imageLink'].append(z)
                else:
                  cat_names['imageLink'].append(str(tt['imageLink'][x]).split('"')[4])
                if len(zz)>=15:                                
                  cat_names['imageLink1'].append(zz)
                else:
                  cat_names['imageLink1'].append(str(tt['imageLink'][x]).split('"')[6])
            else:
              cat_names['brand'].append(str(url))
              cat_names['imageLink1'].append(str(url))
              cat_names['imageLink1'].append(str(url))

    for tag in soup.findAll("div", {"class": "a-icon-row"}):
            x = tag.findNext("span").text
            xxx = tag.findNext("span", {"class": "a-size-small"}).text
            if len(x)>=1:
              cat_names['rating'].append(x)
            else:
              cat_names['ratingCount'].append(str(url))
            if len(xxx)>=1:
              cat_names['ratingCount'].append(xxx)
            else:
              cat_names['ratingCount'].append(str(url))
    for tag in soup.findAll("span", {"class": "a-size-base a-color-price"}):
            x = tag.findNext("span",{"class":"_p13n-zg-list-grid-desktop_price_p13n-sc-price__3mJ9Z"}).text
            if len(x)>=1:
              cat_names['price'].append(x)
            else:
              cat_names['price'].append(str(url))
  except:
    print('first 50, error with link: '+ str(url))

  time.sleep(random.randint(1,wait_time))
#-------------------------------------------------------------------------------------------------------------
  try:
    html1 = requests.get(url2,headers = headers).text
    soup1 = bs4.BeautifulSoup(html1, "html.parser")
    for tag in soup1.findAll("div", {"class": "a-section a-spacing-mini _p13n-zg-list-grid-desktop_maskStyle_noop__3Xbw5"}):
            tt = {'imageLink':[]}
            tt['imageLink'].append(tag.findAll("img"))
            if len(tt['imageLink'])>=1:
              for x in range(len(tt['imageLink'])):
                cat_names1['brand'].append(str(tt['imageLink'][x]).split('"')[1])
                z = str(tt['imageLink'][x]).split('"')[5]
                zz = str(tt['imageLink'][x]).split('"')[7]
                if len(z)>=15:
                  cat_names1['imageLink'].append(z)
                else:
                  cat_names1['imageLink'].append(str(tt['imageLink'][x]).split('"')[4])
                if len(zz)>=15:                                
                  cat_names1['imageLink1'].append(zz)
                else:
                  cat_names1['imageLink1'].append(str(tt['imageLink'][x]).split('"')[6])
            else:
              cat_names1['brand'].append(str(url2))
              cat_names1['imageLink'].append(str(url2))
              cat_names1['imageLink1'].append(str(url2))
            
    for tag in soup.findAll("div", {"class": "a-icon-row"}):
            x = tag.findNext("span").text
            xxx = tag.findNext("span").text
            if len(x)>=1:
              cat_names1['rating'].append(x)
            else:
              cat_names1['rating'].append(str(url2))
            if len(xxx)>=1:
              cat_names1['ratingCount'].append(xxx)
            else:
              cat_names1['ratingCount'].append(str(url))

    for tag in soup.findAll("span", {"class": "a-size-base a-color-price"}):
            x = tag.findNext("span",{"class":"_p13n-zg-list-grid-desktop_price_p13n-sc-price__3mJ9Z"}).text
            if len(x)>=1:
              cat_names1['price'].append(x)
            else:
              cat_names1['price'].append(str(url2))

    print(len(cat_names1['imageLink']))
    print(len(cat_names1['imageLink1']))
    print(len(cat_names1['brand']))
    print(len(cat_names1['rating']))
    print(len(cat_names1['price']))

  except:
    print('second 50, error with link: '+ url2)
  
  time.sleep(random.randint(1,wait_time))
# Out:
#                                             imageLink  \
# 0   https://images-na.ssl-images-amazon.com/images...
# 1   https://images-na.ssl-images-amazon.com/images...
# 2   https://images-na.ssl-images-amazon.com/images...
# 3   https://images-na.ssl-images-amazon.com/images...
# 4   https://images-na.ssl-images-amazon.com/images...
# 5   https://images-na.ssl-images-amazon.com/images...
# 6   https://images-na.ssl-images-amazon.com/images...
# 7   https://images-na.ssl-images-amazon.com/images...
# 8   https://images-na.ssl-images-amazon.com/images...
# 9   https://images-na.ssl-images-amazon.com/images...
# 10  https://images-na.ssl-images-amazon.com/images...
# 11  https://images-na.ssl-images-amazon.com/images...
# 12  https://images-na.ssl-images-amazon.com/images...
# 13  https://images-na.ssl-images-amazon.com/images...
# 14  https://images-na.ssl-images-amazon.com/images...
# 55          Blink Video Doorbell Corner Mount – Black  4.4 out of 5 stars
# 56   Omni Series 4K UHD smart TV with Dolby Vision...  4.6 out of 5 stars
# 57  Amazon eero Beacon mesh WiFi range extender (a...  4.7 out of 5 stars
# 58             Ring Alarm Glass Break Sensor – 1-pack  4.3 out of 5 stars
# 59  Toshiba 32-inch Class V35 Series LED HD Smart ...  4.6 out of 5 stars
#
#    ratingCount    price
# 0       52,507   $29.99
# 1        4,931   $29.99
# 2        4,931   $29.99
# 3        1,458   $29.99
# 4        4,931   $29.99
# 5          301   $24.99
# 6          928    $5.99
# 7          433   $12.99
# 8        3,824   $39.99
# 9          218   $29.99
# 10         192  $139.98
# 11     108,503  $129.98
# 12         270   $12.99
# 13       3,824   $39.99
# 14       3,824   $39.99
# 15          78   $29.99
# 16         248   $39.99
# 17         218   $29.99
# 18       3,824   $39.99
# 19         954   $29.99
# 20          52   $59.99
# 21      72,124   $42.98
# 22           1   $29.99
# 23         416   $24.99
# 24       1,886   $19.99
# 25          27   $39.99
# 26         207   $14.99
# 27         275   $12.99
# 28         675   $49.99
# 29       1,886   $19.99
# 30      72,124   $37.99
# 31       6,305  $104.99
# 32      38,875   $54.99
# 33      26,810   $49.99
# 34       5,109   $69.99
# 35      52,507   $29.99
# 36       3,256   $29.99
# 37       2,570  $189.99
# 38       7,056  $349.99
# 39       6,305  $119.99
# 40       2,679   $39.99
# 41       7,056  $319.99
# 42         589  $114.99
# 43       3,911  $499.99
# 44       7,056  $279.99
# 45      89,273  $119.99
# 46       3,911  $369.99
# 47       3,492  $249.99
# 48      89,273  $119.99
# 49         271  $299.99
# 50         415  $279.98
# 51         191   $24.99
# 52       6,768   $79.99
# 53       2,679   $39.99
# 54         589  $114.99
# 55       2,084    $7.99
# 56       3,911  $749.99
# 57       4,787  $119.00
# 58          81   $39.99
# 59         480  $159.99

# %%
df = pd.DataFrame(cat_names)
df1 = pd.DataFrame(cat_names1)

def find_number(text):
    num = re.findall(r'[0-9]+',text)
    return " ".join(num)
df['rating_num']=df['rating'].apply(lambda x: find_number(x))
df1['rating_num']=df1['rating'].apply(lambda x: find_number(x))
df['price']=df1['price'].apply(lambda x: find_number(x))
df['price']=df1['price'].apply(lambda x: find_number(x))


listt = []
for x in range(len(df)):
  try:
    listt.append((int(df['rating_num'].iloc[x].split()[0])+int(df['rating_num'].iloc[x].split()[1])*.1)/int(df['rating_num'].iloc[x].split()[2]))
  except:
    listt.append('error')

df['rating_num'] = listt
listt = []
for x in range(len(df1)):
  try:
    listt.append((int(df1['rating_num'].iloc[x].split()[0])+int(df1['rating_num'].iloc[x].split()[1])*.1)/int(df1['rating_num'].iloc[x].split()[2]))
  except:
    listt.append('error')

df1['rating_num'] = listt

listt = []
for x in range(len(df)):
  try:
    listt.append(df['price'].iloc[x].replace('$',""))
  except:
    listt.append('error')
df['price'] = listt

listt = []
for x in range(len(df1)):
  try:
    listt.append(df1['price'].iloc[x].replace('$',""))
  except:
    listt.append('error')
df1['price'] = listt

pieces = (df1,df)
df_final = pd.concat(pieces, ignore_index = True)
df_final = df_final.drop(columns ='rating')
df_final

# %%
len(cat_names['brand'])
# Out:
# 10947
